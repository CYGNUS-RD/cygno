# %%
import numpy as np
import uproot

# %%
tf = uproot.open("/jupyter-workspace/cloud-storage/cygno-analysis/RECO/Winter23/reco_run23035_3D.root")

# %%
tf = uproot.open("https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run22955_3D.root")

# %%
sc_integral = tf["Events;1/sc_integral"].array(library="np")
run = tf["Events;1/run"].array(library="np")

# %%
tf["Events;1"].show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# run                  | int32_t                  | AsDtype('>i4')
# event                | int32_t                  | AsDtype('>i4')
# pedestal_run         | int32_t                  | AsDtype('>i4')
# cmos_integral        | float                    | AsDtype('>f4')
# cmos_mean            | float                    | AsDtype('>f4')
# cmos_rms             | float                    | AsDtype('>f4')
# t_DBSCAN             | float                    | AsDtype('>f4')
# t_variables          | float                    | AsDtype('>f4')
# lp_len               | float                    | AsDtype('>f4')
# t_pedsub             | float                    | AsDtype('>f4')
# t_saturation         | float                    | AsDtype('>f4')
# t_zerosup            | float                    | AsDtype('>f4')
# t_xycut              | float                    | AsDtype('>f4')
# t_rebin              | float                    | AsDtype('>f4')
# t_medianfilter       | float                    | AsDtype('>f4')
# t_noisered           | float                    | AsDtype('>f4')
# nSc                  | uint32_t                 | AsDtype('>u4')
# sc_size              | float[]                  | AsJagged(AsDtype('>f4'))
# sc_nhits             | float[]                  | AsJagged(AsDtype('>f4'))
# sc_integral          | float[]                  | AsJagged(AsDtype('>f4'))
# sc_corrintegral      | float[]                  | AsJagged(AsDtype('>f4'))
# sc_rms               | float[]                  | AsJagged(AsDtype('>f4'))
# sc_energy            | float[]                  | AsJagged(AsDtype('>f4'))
# sc_pathlength        | float[]                  | AsJagged(AsDtype('>f4'))
# sc_redpixIdx         | float[]                  | AsJagged(AsDtype('>f4'))
# nRedpix              | uint32_t                 | AsDtype('>u4')
# redpix_ix            | int32_t[]                | AsJagged(AsDtype('>i4'))
# redpix_iy            | int32_t[]                | AsJagged(AsDtype('>i4'))
# redpix_iz            | float[]                  | AsJagged(AsDtype('>f4'))
# sc_theta             | float[]                  | AsJagged(AsDtype('>f4'))
# sc_length            | float[]                  | AsJagged(AsDtype('>f4'))
# sc_width             | float[]                  | AsJagged(AsDtype('>f4'))
# sc_longrms           | float[]                  | AsJagged(AsDtype('>f4'))
# sc_latrms            | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lfullrms          | float[]                  | AsJagged(AsDtype('>f4'))
# sc_tfullrms          | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lp0amplitude      | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lp0prominence     | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lp0fwhm           | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lp0mean           | float[]                  | AsJagged(AsDtype('>f4'))
# sc_tp0fwhm           | float[]                  | AsJagged(AsDtype('>f4'))
# sc_xmean             | float[]                  | AsJagged(AsDtype('>f4'))
# sc_ymean             | float[]                  | AsJagged(AsDtype('>f4'))
# sc_xmax              | float[]                  | AsJagged(AsDtype('>f4'))
# sc_xmin              | float[]                  | AsJagged(AsDtype('>f4'))
# sc_ymax              | float[]                  | AsJagged(AsDtype('>f4'))
# sc_ymin              | float[]                  | AsJagged(AsDtype('>f4'))
# sc_pearson           | float[]                  | AsJagged(AsDtype('>f4'))
# sc_tgaussamp         | float[]                  | AsJagged(AsDtype('>f4'))
# sc_tgaussmean        | float[]                  | AsJagged(AsDtype('>f4'))
# sc_tgausssigma       | float[]                  | AsJagged(AsDtype('>f4'))
# sc_tchi2             | float[]                  | AsJagged(AsDtype('>f4'))
# sc_tstatus           | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lgaussamp         | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lgaussmean        | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lgausssigma       | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lchi2             | float[]                  | AsJagged(AsDtype('>f4'))
# sc_lstatus           | float[]                  | AsJagged(AsDtype('>f4'))
# Lime_pressure        | float                    | AsDtype('>f4')
# Atm_pressure         | float                    | AsDtype('>f4')
# Lime_temperature     | float                    | AsDtype('>f4')
# Atm_temperature      | float                    | AsDtype('>f4')
# Humidity             | float                    | AsDtype('>f4')

# %%
names = tf["Events;1"].keys()

# %%
names
# Out:
# ['run',
#  'event',
#  'pedestal_run',
#  'cmos_integral',
#  'cmos_mean',
#  'cmos_rms',
#  't_DBSCAN',
#  't_variables',
#  'lp_len',
#  't_pedsub',
#  't_saturation',
#  't_zerosup',
#  't_xycut',
#  't_rebin',
#  't_medianfilter',
#  't_noisered',
#  'nSc',
#  'sc_size',
#  'sc_nhits',
#  'sc_integral',
#  'sc_corrintegral',
#  'sc_rms',
#  'sc_energy',
#  'sc_pathlength',
#  'sc_redpixIdx',
#  'nRedpix',
#  'redpix_ix',
#  'redpix_iy',
#  'redpix_iz',
#  'sc_theta',
#  'sc_length',
#  'sc_width',
#  'sc_longrms',
#  'sc_latrms',
#  'sc_lfullrms',
#  'sc_tfullrms',
#  'sc_lp0amplitude',
#  'sc_lp0prominence',
#  'sc_lp0fwhm',
#  'sc_lp0mean',
#  'sc_tp0fwhm',
#  'sc_xmean',
#  'sc_ymean',
#  'sc_xmax',
#  'sc_xmin',
#  'sc_ymax',
#  'sc_ymin',
#  'sc_pearson',
#  'sc_tgaussamp',
#  'sc_tgaussmean',
#  'sc_tgausssigma',
#  'sc_tchi2',
#  'sc_tstatus',
#  'sc_lgaussamp',
#  'sc_lgaussmean',
#  'sc_lgausssigma',
#  'sc_lchi2',
#  'sc_lstatus',
#  'Lime_pressure',
#  'Atm_pressure',
#  'Lime_temperature',
#  'Atm_temperature',
#  'Humidity']

# %%
var = tf["Events;1/"+names[19]].array(library="np")
for j in range(len(var)):
    print(var[j].mean())
# Out:
# 10006.463
# 2174.308
# 5133.7607
# 2811.746
# 3039.9893
# 1512.8098
# 1798.8666
# 2710.1213
# 3227.7888
# 2077.272
# 2542.6235
# 3153.0217
# 1982.3096
# 2116.0276
# 4614.067
# 1986.1913
# 1899.6837
# 2465.031
# 2268.8376
# 1241.897
# 1845.1302
# 1799.7937
# 2148.222
# 1346.8005
# 2338.1785
# 2826.672
# 2559.378
# 2320.6074
# 1508.8655
# 2268.212
# 1801.1406
# 2525.523
# 2810.4468
# 1609.3842
# 3229.4902
# 1827.0564
# 2058.188
# 2778.7502
# 2112.9646
# 2532.1174
# 2208.778
# 1194.0985
# 2451.387
# 2238.6282
# 2283.3174
# 2394.1301
# 2127.585
# 2879.9521
# 2997.968
# 3492.4373
# 2035.2517
# 2043.523
# 2778.814
# 1514.1919
# 1633.83
# 2475.8542
# 2298.0205
# 1380.8887
# 2198.0964
# 1859.7465
# 1850.9724
# 2402.133
# 2908.22
# 1352.845
# 1544.5992
# 1610.9387
# 3714.785
# 1782.7529
# 1272.6013
# 2898.445
# 1370.9071
# 1799.9072
# 2357.7683
# 3465.0708
# 3489.6526
# 1607.0297
# 2068.1438
# 1407.34
# 3579.6428
# 2101.5144
# 1959.2872
# 2378.028
# 2979.2947
# 2514.9294
# 1050.6099
# 2226.284
# 2718.6384
# 1211.3176
# 2510.1792
# 2441.8486
# 1708.495
# 2114.4478
# 4315.774
# 1911.6387
# 1799.9005
# 1493.0806
# 1954.1005
# 1887.382
# 2763.2043
# 3632.0393
# 1923.8934

# %%
len(tf["Events;1/"+names[19]].array(library="np"))
# Out:
# 101

# %%
values = []
columns = []
for i, name in enumerate(names):
    var = tf["Events;1/"+name].array(library="np")
    if var[0].ndim == 0:
        print(i, name, var.mean(), var.std())
        columns.append(name+"_mean")
        values.append(var.mean())
        columns.append(name+"_std")
        values.append(var.std())
        
#    elif (tf["Events;1/"+name].array(library="np")[0]).ndim == 1:
        
    else:
        print(i, name, var[0].ndim)
# Out:
# 0 run 22955.0 0.0
# 1 event 50.0 29.154759474226502
# 2 pedestal_run 22955.0 0.0
# 3 cmos_integral 5133500.0 30355.502
# 4 cmos_mean 0.96704924 0.005718369
# 5 cmos_rms 2.5484166 0.09367029
# 6 t_DBSCAN 18.744038 4.09138
# 7 t_variables 5.051228 1.6890601
# 8 lp_len 2560.703 594.64435
# 9 t_pedsub 0.0955791 0.057132035
# 10 t_saturation 2.3084074e-06 3.2292354e-07
# 11 t_zerosup 0.32831207 0.1543659
# 12 t_xycut 8.8240085e-05 0.0004851557
# 13 t_rebin 0.09261915 0.014417395
# 14 t_medianfilter 0.68732613 0.08285965
# 15 t_noisered 0.015700161 0.0045757857
# 16 nSc 28.97029702970297 4.938143005970657
# 17 sc_size 1
# 18 sc_nhits 1
# 19 sc_integral 1
# 20 sc_corrintegral 1
# 21 sc_rms 1
# 22 sc_energy 1
# 23 sc_pathlength 1
# 24 sc_redpixIdx 1
# 25 nRedpix 32573.30693069307 10266.68801160217
# 26 redpix_ix 1
# 27 redpix_iy 1
# 28 redpix_iz 1
# 29 sc_theta 1
# 30 sc_length 1
# 31 sc_width 1
# 32 sc_longrms 1
# 33 sc_latrms 1
# 34 sc_lfullrms 1
# 35 sc_tfullrms 1
# 36 sc_lp0amplitude 1
# 37 sc_lp0prominence 1
# 38 sc_lp0fwhm 1
# 39 sc_lp0mean 1
# 40 sc_tp0fwhm 1
# 41 sc_xmean 1
# 42 sc_ymean 1
# 43 sc_xmax 1
# 44 sc_xmin 1
# 45 sc_ymax 1
# 46 sc_ymin 1
# 47 sc_pearson 1
# 48 sc_tgaussamp 1
# 49 sc_tgaussmean 1
# 50 sc_tgausssigma 1
# 51 sc_tchi2 1
# 52 sc_tstatus 1
# 53 sc_lgaussamp 1
# 54 sc_lgaussmean 1
# 55 sc_lgausssigma 1
# 56 sc_lchi2 1
# 57 sc_lstatus 1
# 58 Lime_pressure 0.912852 6.0249437e-05
# 59 Atm_pressure 0.9043957 6.491854e-05
# 60 Lime_temperature 20.816967 0.00022794007
# 61 Atm_temperature 21.607801 0.015136837
# 62 Humidity -1.7345715 0.00646346

# %%
columns, values
# Out:
# (['run_main',
#   'run_std',
#   'event_main',
#   'event_std',
#   'pedestal_run_main',
#   'pedestal_run_std',
#   'cmos_integral_main',
#   'cmos_integral_std',
#   'cmos_mean_main',
#   'cmos_mean_std',
#   'cmos_rms_main',
#   'cmos_rms_std',
#   't_DBSCAN_main',
#   't_DBSCAN_std',
#   't_variables_main',
#   't_variables_std',
#   'lp_len_main',
#   'lp_len_std',
#   't_pedsub_main',
#   't_pedsub_std',
#   't_saturation_main',
#   't_saturation_std',
#   't_zerosup_main',
#   't_zerosup_std',
#   't_xycut_main',
#   't_xycut_std',
#   't_rebin_main',
#   't_rebin_std',
#   't_medianfilter_main',
#   't_medianfilter_std',
#   't_noisered_main',
#   't_noisered_std',
#   'nSc_main',
#   'nSc_std',
#   'nRedpix_main',
#   'nRedpix_std',
#   'Lime_pressure_main',
#   'Lime_pressure_std',
#   'Atm_pressure_main',
#   'Atm_pressure_std',
#   'Lime_temperature_main',
#   'Lime_temperature_std',
#   'Atm_temperature_main',
#   'Atm_temperature_std',
#   'Humidity_main',
#   'Humidity_std'],
#  [22955.0,
#   0.0,
#   50.0,
#   29.154759474226502,
#   22955.0,
#   0.0,
#   5133500.0,
#   30355.502,
#   0.96704924,
#   0.005718369,
#   2.5484166,
#   0.09367029,
#   18.744038,
#   4.09138,
#   5.051228,
#   1.6890601,
#   2560.703,
#   594.64435,
#   0.0955791,
#   0.057132035,
#   2.3084074e-06,
#   3.2292354e-07,
#   0.32831207,
#   0.1543659,
#   8.8240085e-05,
#   0.0004851557,
#   0.09261915,
#   0.014417395,
#   0.68732613,
#   0.08285965,
#   0.015700161,
#   0.0045757857,
#   28.97029702970297,
#   4.938143005970657,
#   32573.30693069307,
#   10266.68801160217,
#   0.912852,
#   6.0249437e-05,
#   0.9043957,
#   6.491854e-05,
#   20.816967,
#   0.00022794007,
#   21.607801,
#   0.015136837,
#   -1.7345715,
#   0.00646346])

# %%
MYSQL_DATABASE="cygno_db"
MYSQL_PASSWORD="e3b46beda9650197978b7b7e80464f73"
MYSQL_IP="131.154.96.221"
MYSQL_USER="cygno_producer"
MYSQL_PORT=6033

# %%
import mysql.connector
import numpy as np
import uproot
connection = mysql.connector.connect(
          host=MYSQL_IP,
          user=MYSQL_USER,
          password=MYSQL_PASSWORD,
          database=MYSQL_DATABASE,
          port=MYSQL_PORT
        )

# %%
sql = "SELECT * FROM `Runlog`  WHERE `online_reco_status` = 1 AND `pedestal_run` = 0 ORDER BY `run_number` DESC LIMIT 1;"

# %%
import pandas as pd
sql_value = pd.read_sql(sql, connection)

# %%
run_number = sql_value.run_number[0]

# %%
run_number
# Out:
# 24202

# %%
tf = uproot.open("https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run{:5d}_3D.root".format(run_number))

# %%
names = tf["Events;1"].keys()

# %%
values = []
columns = []
for i, name in enumerate(names):
    var = tf["Events;1/"+name].array(library="np")
    if var[0].ndim == 0:
        print(i, name, var.mean(), var.std())
        columns.append(name+"_mean")
        values.append(var.mean())
        columns.append(name+"_std")
        values.append(var.std())
        
#    elif (tf["Events;1/"+name].array(library="np")[0]).ndim == 1:
        
    else:
        print(i, name, var[0].ndim)
# Out:
# 0 run 24028.0 0.0
# 1 event 199.5 115.46969299344309
# 2 pedestal_run 24023.0 0.0
# 3 cmos_integral 5406331.0 138567.06
# 4 cmos_mean 1.0184451 0.026103275
# 5 cmos_rms 2.6939898 0.31005952
# 6 t_DBSCAN 14.5560055 4.4641933
# 7 t_variables 6.337544 1.8369608
# 8 lp_len 7450.545 2069.338
# 9 t_pedsub 0.039128818 0.004513294
# 10 t_saturation 2.462715e-06 1.9681313e-06
# 11 t_zerosup 0.11328878 0.008436792
# 12 t_xycut 4.8254846e-05 1.3647874e-05
# 13 t_rebin 0.04608928 0.0037477992
# 14 t_medianfilter 0.34731865 0.015530345
# 15 t_noisered 0.008175754 0.0013616816
# 16 nSc 20.9875 4.457279859959435
# 17 sc_size 1
# 18 sc_nhits 1
# 19 sc_integral 1
# 20 sc_corrintegral 1
# 21 sc_rms 1
# 22 sc_energy 1
# 23 sc_pathlength 1
# 24 sc_redpixIdx 1
# 25 nRedpix 112534.68 33322.853018575704
# 26 redpix_ix 1
# 27 redpix_iy 1
# 28 redpix_iz 1
# 29 sc_theta 1
# 30 sc_length 1
# 31 sc_width 1
# 32 sc_longrms 1
# 33 sc_latrms 1
# 34 sc_lfullrms 1
# 35 sc_tfullrms 1
# 36 sc_lp0amplitude 1
# 37 sc_lp0prominence 1
# 38 sc_lp0fwhm 1
# 39 sc_lp0mean 1
# 40 sc_tp0fwhm 1
# 41 sc_xmean 1
# 42 sc_ymean 1
# 43 sc_xmax 1
# 44 sc_xmin 1
# 45 sc_ymax 1
# 46 sc_ymin 1
# 47 sc_pearson 1
# 48 sc_tgaussamp 1
# 49 sc_tgaussmean 1
# 50 sc_tgausssigma 1
# 51 sc_tchi2 1
# 52 sc_tstatus 1
# 53 sc_lgaussamp 1
# 54 sc_lgaussmean 1
# 55 sc_lgausssigma 1
# 56 sc_lchi2 1
# 57 sc_lstatus 1
# 58 Lime_pressure 0.9089804 4.7973597e-05
# 59 Atm_pressure 0.90054655 0.00021409642
# 60 Lime_temperature 20.515497 0.02175128
# 61 Atm_temperature 21.07822 0.24058844
# 62 Humidity -3.0386305 0.102321446

# %%
def push_panda_table_sql(connection, table_name, df):
    import pandas as pd
    try:
        mycursor=connection.cursor()
        mycursor.execute("SHOW TABLES LIKE '"+table_name+"'")
        result = mycursor.fetchone()
        if not result:
            cols = "`,`".join([str(i) for i in df.columns.tolist()])
            db_to_crete = "CREATE TABLE `"+table_name+"` ("+' '.join(["`"+x+"` REAL," for x in df.columns.tolist()])[:-1]+")"
            print ("[Table {:s} created into SQL Server]".format(table_name))
            mycursor = connection.cursor()
            mycursor.execute(db_to_crete)

        cols = "`,`".join([str(i) for i in df.columns.tolist()])

        for i,row in df.iterrows():
            sql = "INSERT INTO `"+table_name+"` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
            mycursor.execute(sql, tuple(row.astype(str)))
            connection.commit()

        mycursor.close()
        return 0 
    except:
        return -1
    

import pandas as pd
df = pd.DataFrame(columns = columns)
df.loc[0] = values
table_name = "SlowReco"
push_panda_table_sql(connection,table_name, df)
# Out:
# 0

# %%
sqlLog = "SELECT * FROM `Runlog`  WHERE `online_reco_status` = 1 AND `pedestal_run` = 0 ORDER BY `run_number` DESC LIMIT 100;"
sqlRec = "SELECT * FROM `SlowReco` ORDER BY `run_mean` DESC LIMIT 100;"
sql_Log = pd.read_sql(sqlLog, connection)
sql_Rec = pd.read_sql(sqlRec, connection)

# %%
sql_Rec
# Out:
#    run_main  run_std  event_main   event_std  pedestal_run_main  \
# 0   24028.0      0.0       199.5  115.469693            24023.0
# 1   23924.0      0.0       202.0  116.913073            23918.0
#
#    pedestal_run_std  cmos_integral_main  cmos_integral_std  cmos_mean_main  \
# 0               0.0           5406331.0      138567.062500        1.018445
# 1               0.0           5407090.5      132448.203125        1.018588
#
#    cmos_mean_std  ...  Lime_pressure_main  Lime_pressure_std  \
# 0       0.026103  ...            0.908980           0.000048
# 1       0.024951  ...            0.909012           0.000080
#
#    Atm_pressure_main  Atm_pressure_std  Lime_temperature_main  \
# 0           0.900547          0.000214              20.515497
# 1           0.900292          0.000208              20.514784
#
#    Lime_temperature_std  Atm_temperature_main  Atm_temperature_std  \
# 0              0.021751             21.078220             0.240588
# 1              0.019240             21.059786             0.217580
#
#    Humidity_main  Humidity_std
# 0      -3.038630      0.102321
# 1      -2.302453      0.092822
#
# [2 rows x 46 columns]

# %%
sql_Log
# Out:
#     run_number run_description          start_time  exposure_sec  GEM3_V  \
# 0        24028   AmBe Campaign 2023-08-03 13:01:31           0.3   440.0
# 1        24026   AmBe Campaign 2023-08-03 12:48:19           0.3   440.0
# 2        24022   AmBe Campaign 2023-08-03 12:25:56           0.3   440.0
# 3        24021   AmBe Campaign 2023-08-03 12:21:54           0.3   440.0
# 4        24019   AmBe Campaign 2023-08-03 12:14:16           0.3   440.0
# ..         ...             ...                 ...           ...     ...
# 95       23887   AmBe Campaign 2023-08-02 23:17:24           0.3   440.0
# 96       23886   AmBe Campaign 2023-08-02 23:10:47           0.3   440.0
# 97       23884   AmBe Campaign 2023-08-02 22:59:48           0.3   440.0
# 98       23883   AmBe Campaign 2023-08-02 22:52:30           0.3   440.0
# 99       23882   AmBe Campaign 2023-08-02 22:45:22           0.3   440.0
#
#     GEM2_V  GEM1_V   T2_V   T1_V  DRIFT_V  ...  shielding_configuration  \
# 0    440.0   440.0  500.0  500.0    960.0  ...                        2
# 1    440.0   440.0  500.0  500.0    960.0  ...                        2
# 2    440.0   440.0  500.0  500.0    960.0  ...                        2
# 3    440.0   440.0  500.0  500.0    960.0  ...                        2
# 4    440.0   440.0  500.0  500.0    960.0  ...                        2
# ..     ...     ...    ...    ...      ...  ...                      ...
# 95   440.0   440.0  500.0  500.0    960.0  ...                        2
# 96   440.0   440.0  500.0  500.0    960.0  ...                        2
# 97   440.0   440.0  500.0  500.0    960.0  ...                        2
# 98   440.0   440.0  500.0  500.0    960.0  ...                        2
# 99   440.0   440.0  500.0  500.0    960.0  ...                        2
#
#              stop_time  number_of_events  storage_local_status  \
# 0  2023-08-03 13:07:45             400.0                     1
# 1  2023-08-03 12:54:40             401.0                     1
# 2  2023-08-03 12:28:56             303.0                     1
# 3  2023-08-03 12:25:53             403.0                     1
# 4  2023-08-03 12:18:14             405.0                     1
# ..                 ...               ...                   ...
# 95 2023-08-02 23:24:07             401.0                     1
# 96 2023-08-02 23:17:20             401.0                     1
# 97 2023-08-02 23:07:07             400.0                     1
# 98 2023-08-02 22:59:41             401.0                     1
# 99 2023-08-02 22:52:27             401.0                     1
#
#     storage_cloud_status  storage_tape_status   file_size  \
# 0                      1                    1  1447541703
# 1                      1                    1  1451614473
# 2                      1                    1  1148768673
# 3                      1                    1  1530992866
# 4                      1                    1  1533707191
# ..                   ...                  ...         ...
# 95                     1                    1  1451775385
# 96                     1                    1  1450237954
# 97                     1                    1  1446672940
# 98                     1                    1  1450776946
# 99                     1                    1  1450171025
#
#                        file_checksum file_s3_tag  online_reco_status
# 0   c300ffbaf5bf92e9c4ff43f2afc4ac13        LNGS                   1
# 1   2bd2188e365bbaeda49c14c9c8b044a7        LNGS                   1
# 2   f91216e3f09b6339967af7239a94b1a1        LNGS                   1
# 3   3fc4f437e18184bed98ee3dd0173fbb9        LNGS                   1
# 4   6e7313b2873972202e92464ee1b4be13        LNGS                   1
# ..                               ...         ...                 ...
# 95  a607c9179a41c28db0bccbbe9b4e2ccc        LNGS                   1
# 96  984630c76d45bc19e4e59d6c6c5b3d0b        LNGS                   1
# 97  48275549ced18e6402860241ac947518        LNGS                   1
# 98  c5728356af4f1b917100fbf465b39d73        LNGS                   1
# 99  5456f9e0b3cf3a3099a5599a3f346967        LNGS                   1
#
# [100 rows x 38 columns]

# %%
MYSQL_DATABASE="cygno_db"
MYSQL_PASSWORD="e3b46beda9650197978b7b7e80464f73"
MYSQL_IP="131.154.96.221"
MYSQL_USER="cygno_producer"
MYSQL_PORT=6033

import numpy as np
import uproot
import pandas as pd
import mysql.connector
import os
import requests
from datetime import datetime

def push_panda_table_sql(connection, table_name, df):
    try:
        mycursor=connection.cursor()
        mycursor.execute("SHOW TABLES LIKE '"+table_name+"'")
        result = mycursor.fetchone()
        if not result:
            cols = "`,`".join([str(i) for i in df.columns.tolist()])
            db_to_crete = "CREATE TABLE `"+table_name+"` ("+' '.join(["`"+x+"` REAL," for x in df.columns.tolist()])[:-1]+")"
            print ("[Table {:s} created into SQL Server]".format(table_name))
            mycursor = connection.cursor()
            mycursor.execute(db_to_crete)

        cols = "`,`".join([str(i) for i in df.columns.tolist()])

        for i,row in df.iterrows():
            sql = "INSERT INTO `"+table_name+"` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
            mycursor.execute(sql, tuple(row.astype(str)))
            connection.commit()

        mycursor.close()
        return 0 
    except:
        return -1
    
def GetLY(tf):
#    rootfile = uproot.open('/jupyter-workspace/cloud-storage/cygno-analysis/RECO/Winter23/reco_run{0:05d}_3D.root'.format(run))
    df_A = tf['Events'].arrays(['sc_rms', 'sc_tgausssigma', 'sc_width', 'sc_length', 'sc_xmean', 'sc_ymean', 'sc_integral'], library = 'pd')


    sel   = df_A[(df_A['sc_rms'] > 6)&
                 (0.152 * df_A['sc_tgausssigma'] > 0.5) &
                 (np.sqrt((df_A['sc_xmean']-2304/2)**2 + (df_A['sc_ymean']-2304/2)**2) < 800)  &
                 (df_A['sc_integral'] > 30_000) & (df_A['sc_integral']<300_000)
                ].copy()

    p = np.array([7.51266058e-02, -1.32492111e+03])

    return p[0]*np.mean(sel['sc_integral'])+p[1], p[0]*np.std(sel['sc_integral']) / np.sqrt(len(sel))

def main(verbose=False):
    connection = mysql.connector.connect(
          host=MYSQL_IP,
          user=MYSQL_USER,
          password=MYSQL_PASSWORD,
          database=MYSQL_DATABASE,
          port=MYSQL_PORT
        )
    
    sqlLog = "SELECT * FROM `Runlog`  WHERE `online_reco_status` = 1 AND `pedestal_run` = 0 ORDER BY `run_number` DESC LIMIT 10;"
    sqlRec = "SELECT * FROM `SlowReco` ORDER BY `run_mean` DESC LIMIT 100;"
    sql_Log = pd.read_sql(sqlLog, connection)
    try:
        sql_Rec = pd.read_sql(sqlRec, connection)
    except:
        sql_Rec = pd.DataFrame(columns = ['run_mean'])
        sql_Rec.loc[0] = 0
    for i, run in enumerate(sql_Log.run_number):
        if not (run in sql_Rec.run_mean.astype(int).tolist()):
            try:
                file_url = "https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run{:5d}_3D.root".format(run)
                tf = uproot.open(file_url)
                names = tf["Events;1"].keys()
                values = []
                columns = []
                for i, name in enumerate(names):
                    var = tf["Events;1/"+name].array(library="np")
                    if var[0].ndim == 0:
                        columns.append(name+"_mean")
                        values.append(var.mean())
                        columns.append(name+"_std")
                        values.append(var.std())
                val_LY = GetLY(tf)
                columns.append("LY_mean")
                values.append(val_LY[0])
                columns.append("LY_std")
                values.append(val_LY[1])
                print(values)
                df = pd.DataFrame(columns = columns)
                df.loc[0] = values
                table_name = "SlowReco"
                push_panda_table_sql(connection,table_name, df)
            except Exception as e:
                print('ERROR >>> {}'.format(e))
                continue
    print ("DONE")
main()
# Out:
# [24041.0, 0.0, 200.5, 116.04704505788446, 24034.0, 0.0, 5410784.0, 116428.29, 1.0192842, 0.021932771, 2.66885, 0.20261803, 14.8696165, 4.551399, 6.4647017, 1.8609177, 7699.754, 2144.8271, 0.03823729, 0.0049962876, 2.8142297e-06, 4.296162e-06, 0.11206423, 0.009938586, 4.6795245e-05, 1.8421591e-05, 0.046332374, 0.0049323756, 0.34575343, 0.015214686, 0.008077215, 0.0007534842, 20.604477611940297, 4.395302767575062, 116548.05970149254, 34591.0516493123, 0.90895903, 2.3720027e-05, 0.9003413, 0.00042706248, 20.505392, 0.015572115, 21.00515, 0.17074022, -3.080813, 0.07644971, 8754.227489724972, 542.5838189225822]
# DONE

# %%
import datetime
import os
import time
import requests
run = run_number
file_url = "https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run{:5d}_3D.root".format(run)
print(file_url)
r = requests.head(file_url)
# Out:
# https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24202_3D.root

# %%
r.headers
# Out:
# {'content-type': 'application/octet-stream', 'content-length': '127419961', 'x-static-large-object': 'True', 'etag': '"0081245ee80b0d6bec83581a021a12eb"', 'last-modified': 'Fri, 04 Aug 2023 07:01:10 GMT', 'x-timestamp': '1691132469.05807', 'accept-ranges': 'bytes', 'x-manifest-etag': 'd764796811e9c58a728f123f4052a94d', 'x-trans-id': 'tx9248fafd57e3436bb77c3-0064cca300', 'x-openstack-request-id': 'tx9248fafd57e3436bb77c3-0064cca300', 'date': 'Fri, 04 Aug 2023 07:04:32 GMT'}

# %%
from datetime import datetime

utc_time = datetime.strptime(r.headers['date'], "%a, %d %b %Y %H:%M:%S %Z")
epoch_time = (utc_time - datetime(1970, 1, 1)).total_seconds()

# %%
epoch_time
# Out:
# 1691128379.0

# %%
datetime.fromtimestamp(epoch_time).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2023-08-04 07:52:59'

# %%
#file_url = "https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run{:5d}_3D.root".format(run)
def get_epoch(file_url):
    import requests
    from datetime import datetime
    r = requests.get(file_url)
    utc_time = datetime.strptime(r.headers['last-modified'], "%a, %d %b %Y %H:%M:%S %Z")
    epoch_time = (utc_time - datetime(1970, 1, 1)).total_seconds()
    return epoch_time

# %%
get_epoch(file_url)
# Out:
# 1691132470.0

# %%
from datetime import datetime
datetime.fromtimestamp(get_epoch(file_url)).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2023-08-03 09:39:00'

# %%
file_url
# Out:
# 'https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24202_3D.root'

# %%
import pandas as pd
connection = mysql.connector.connect(
          host=MYSQL_IP,
          user=MYSQL_USER,
          password=MYSQL_PASSWORD,
          database=MYSQL_DATABASE,
          port=MYSQL_PORT
        )
sqlRec = "SELECT * FROM `SlowReco` ORDER BY `run_mean` DESC;"
sqlLog = "SELECT * FROM `Runlog`  WHERE `online_reco_status` = 1 AND `pedestal_run` = 0 ORDER BY `run_number` DESC;"
sql_Rec = pd.read_sql(sqlRec, connection)
sql_Log = pd.read_sql(sqlLog, connection)
connection.close()

# %%
def start2epoch(sql_Log, run):
    date = str(sql_Log[sql_Log.run_number==run].start_time.values[0])
    utc_time = datetime.strptime(date, "%Y-%m-%dT%H:%M:%S.000000000")
    epoch_time = (utc_time - datetime(1970, 1, 1)).total_seconds()
    return epoch_time

# %%
start2epoch(sql_Log, run)
# Out:
# 1691031220.0

# %%
for i, run in enumerate(sql_Rec.run_mean):
    file_url = "https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run{:5d}_3D.root".format(int(run))
    epoch = start2epoch(sql_Log, run)
    con = mysql.connector.connect(
      host=MYSQL_IP,
      user=MYSQL_USER,
      password=MYSQL_PASSWORD,
      database=MYSQL_DATABASE,
      port=MYSQL_PORT
    )
    cursor = con.cursor()
    sql = 'UPDATE `SlowReco` SET `run_epoch`=\'{}\' WHERE `run_mean` = \'{}\';'.format(epoch, int(run))
    print(run, file_url, epoch, sql)
    cursor.execute(sql)
    con.commit()
    con.close()
# Out:
# 24223.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24223_3D.root 1691143959.0 UPDATE `SlowReco` SET `run_epoch`='1691143959.0' WHERE `run_mean` = '24223';
# 24218.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24218_3D.root 1691142103.0 UPDATE `SlowReco` SET `run_epoch`='1691142103.0' WHERE `run_mean` = '24218';
# 24213.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24213_3D.root 1691140016.0 UPDATE `SlowReco` SET `run_epoch`='1691140016.0' WHERE `run_mean` = '24213';
# 24212.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24212_3D.root 1691139603.0 UPDATE `SlowReco` SET `run_epoch`='1691139603.0' WHERE `run_mean` = '24212';
# 24211.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24211_3D.root 1691139202.0 UPDATE `SlowReco` SET `run_epoch`='1691139202.0' WHERE `run_mean` = '24211';
# 24209.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24209_3D.root 1691138567.0 UPDATE `SlowReco` SET `run_epoch`='1691138567.0' WHERE `run_mean` = '24209';
# 24208.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24208_3D.root 1691138165.0 UPDATE `SlowReco` SET `run_epoch`='1691138165.0' WHERE `run_mean` = '24208';
# 24207.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24207_3D.root 1691137745.0 UPDATE `SlowReco` SET `run_epoch`='1691137745.0' WHERE `run_mean` = '24207';
# 24204.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24204_3D.root 1691136551.0 UPDATE `SlowReco` SET `run_epoch`='1691136551.0' WHERE `run_mean` = '24204';
# 24203.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24203_3D.root 1691136138.0 UPDATE `SlowReco` SET `run_epoch`='1691136138.0' WHERE `run_mean` = '24203';
# 24202.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24202_3D.root 1691135707.0 UPDATE `SlowReco` SET `run_epoch`='1691135707.0' WHERE `run_mean` = '24202';
# 24201.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24201_3D.root 1691135287.0 UPDATE `SlowReco` SET `run_epoch`='1691135287.0' WHERE `run_mean` = '24201';
# 24200.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24200_3D.root 1691134890.0 UPDATE `SlowReco` SET `run_epoch`='1691134890.0' WHERE `run_mean` = '24200';
# 24198.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24198_3D.root 1691134263.0 UPDATE `SlowReco` SET `run_epoch`='1691134263.0' WHERE `run_mean` = '24198';
# 24197.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24197_3D.root 1691133856.0 UPDATE `SlowReco` SET `run_epoch`='1691133856.0' WHERE `run_mean` = '24197';
# 24196.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24196_3D.root 1691133448.0 UPDATE `SlowReco` SET `run_epoch`='1691133448.0' WHERE `run_mean` = '24196';
# 24195.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24195_3D.root 1691133031.0 UPDATE `SlowReco` SET `run_epoch`='1691133031.0' WHERE `run_mean` = '24195';
# 24194.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24194_3D.root 1691132624.0 UPDATE `SlowReco` SET `run_epoch`='1691132624.0' WHERE `run_mean` = '24194';
# 24193.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24193_3D.root 1691132235.0 UPDATE `SlowReco` SET `run_epoch`='1691132235.0' WHERE `run_mean` = '24193';
# 24192.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24192_3D.root 1691131842.0 UPDATE `SlowReco` SET `run_epoch`='1691131842.0' WHERE `run_mean` = '24192';
# 24190.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24190_3D.root 1691131034.0 UPDATE `SlowReco` SET `run_epoch`='1691131034.0' WHERE `run_mean` = '24190';
# 24189.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24189_3D.root 1691130626.0 UPDATE `SlowReco` SET `run_epoch`='1691130626.0' WHERE `run_mean` = '24189';
# 24186.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24186_3D.root 1691129617.0 UPDATE `SlowReco` SET `run_epoch`='1691129617.0' WHERE `run_mean` = '24186';
# 24185.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24185_3D.root 1691129214.0 UPDATE `SlowReco` SET `run_epoch`='1691129214.0' WHERE `run_mean` = '24185';
# 24184.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24184_3D.root 1691128794.0 UPDATE `SlowReco` SET `run_epoch`='1691128794.0' WHERE `run_mean` = '24184';
# 24183.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24183_3D.root 1691128384.0 UPDATE `SlowReco` SET `run_epoch`='1691128384.0' WHERE `run_mean` = '24183';
# 24182.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24182_3D.root 1691127976.0 UPDATE `SlowReco` SET `run_epoch`='1691127976.0' WHERE `run_mean` = '24182';
# 24181.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24181_3D.root 1691127582.0 UPDATE `SlowReco` SET `run_epoch`='1691127582.0' WHERE `run_mean` = '24181';
# 24180.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24180_3D.root 1691127189.0 UPDATE `SlowReco` SET `run_epoch`='1691127189.0' WHERE `run_mean` = '24180';
# 24179.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24179_3D.root 1691126779.0 UPDATE `SlowReco` SET `run_epoch`='1691126779.0' WHERE `run_mean` = '24179';
# 24178.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24178_3D.root 1691126371.0 UPDATE `SlowReco` SET `run_epoch`='1691126371.0' WHERE `run_mean` = '24178';
# 24176.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24176_3D.root 1691125753.0 UPDATE `SlowReco` SET `run_epoch`='1691125753.0' WHERE `run_mean` = '24176';
# 24175.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24175_3D.root 1691125354.0 UPDATE `SlowReco` SET `run_epoch`='1691125354.0' WHERE `run_mean` = '24175';
# 24174.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24174_3D.root 1691124936.0 UPDATE `SlowReco` SET `run_epoch`='1691124936.0' WHERE `run_mean` = '24174';
# 24173.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24173_3D.root 1691124519.0 UPDATE `SlowReco` SET `run_epoch`='1691124519.0' WHERE `run_mean` = '24173';
# 24172.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24172_3D.root 1691124118.0 UPDATE `SlowReco` SET `run_epoch`='1691124118.0' WHERE `run_mean` = '24172';
# 24171.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24171_3D.root 1691123705.0 UPDATE `SlowReco` SET `run_epoch`='1691123705.0' WHERE `run_mean` = '24171';
# 24170.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24170_3D.root 1691123294.0 UPDATE `SlowReco` SET `run_epoch`='1691123294.0' WHERE `run_mean` = '24170';
# 24169.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24169_3D.root 1691122856.0 UPDATE `SlowReco` SET `run_epoch`='1691122856.0' WHERE `run_mean` = '24169';
# 24168.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24168_3D.root 1691122435.0 UPDATE `SlowReco` SET `run_epoch`='1691122435.0' WHERE `run_mean` = '24168';
# 24167.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24167_3D.root 1691122014.0 UPDATE `SlowReco` SET `run_epoch`='1691122014.0' WHERE `run_mean` = '24167';
# 24165.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24165_3D.root 1691121377.0 UPDATE `SlowReco` SET `run_epoch`='1691121377.0' WHERE `run_mean` = '24165';
# 24164.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24164_3D.root 1691121006.0 UPDATE `SlowReco` SET `run_epoch`='1691121006.0' WHERE `run_mean` = '24164';
# 24163.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24163_3D.root 1691120586.0 UPDATE `SlowReco` SET `run_epoch`='1691120586.0' WHERE `run_mean` = '24163';
# 24162.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24162_3D.root 1691120166.0 UPDATE `SlowReco` SET `run_epoch`='1691120166.0' WHERE `run_mean` = '24162';
# 24161.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24161_3D.root 1691119769.0 UPDATE `SlowReco` SET `run_epoch`='1691119769.0' WHERE `run_mean` = '24161';
# 24160.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24160_3D.root 1691119331.0 UPDATE `SlowReco` SET `run_epoch`='1691119331.0' WHERE `run_mean` = '24160';
# 24159.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24159_3D.root 1691118932.0 UPDATE `SlowReco` SET `run_epoch`='1691118932.0' WHERE `run_mean` = '24159';
# 24158.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24158_3D.root 1691118554.0 UPDATE `SlowReco` SET `run_epoch`='1691118554.0' WHERE `run_mean` = '24158';
# 24157.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24157_3D.root 1691118141.0 UPDATE `SlowReco` SET `run_epoch`='1691118141.0' WHERE `run_mean` = '24157';
# 24156.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24156_3D.root 1691117710.0 UPDATE `SlowReco` SET `run_epoch`='1691117710.0' WHERE `run_mean` = '24156';
# 24154.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24154_3D.root 1691117112.0 UPDATE `SlowReco` SET `run_epoch`='1691117112.0' WHERE `run_mean` = '24154';
# 24153.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24153_3D.root 1691116695.0 UPDATE `SlowReco` SET `run_epoch`='1691116695.0' WHERE `run_mean` = '24153';
# 24152.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24152_3D.root 1691116293.0 UPDATE `SlowReco` SET `run_epoch`='1691116293.0' WHERE `run_mean` = '24152';
# 24151.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24151_3D.root 1691115914.0 UPDATE `SlowReco` SET `run_epoch`='1691115914.0' WHERE `run_mean` = '24151';
# 24150.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24150_3D.root 1691115531.0 UPDATE `SlowReco` SET `run_epoch`='1691115531.0' WHERE `run_mean` = '24150';
# 24149.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24149_3D.root 1691115111.0 UPDATE `SlowReco` SET `run_epoch`='1691115111.0' WHERE `run_mean` = '24149';
# 24148.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24148_3D.root 1691114690.0 UPDATE `SlowReco` SET `run_epoch`='1691114690.0' WHERE `run_mean` = '24148';
# 24147.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24147_3D.root 1691114272.0 UPDATE `SlowReco` SET `run_epoch`='1691114272.0' WHERE `run_mean` = '24147';
# 24146.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24146_3D.root 1691113855.0 UPDATE `SlowReco` SET `run_epoch`='1691113855.0' WHERE `run_mean` = '24146';
# 24145.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24145_3D.root 1691113434.0 UPDATE `SlowReco` SET `run_epoch`='1691113434.0' WHERE `run_mean` = '24145';
# 24143.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24143_3D.root 1691112787.0 UPDATE `SlowReco` SET `run_epoch`='1691112787.0' WHERE `run_mean` = '24143';
# 24142.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24142_3D.root 1691112368.0 UPDATE `SlowReco` SET `run_epoch`='1691112368.0' WHERE `run_mean` = '24142';
# 24141.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24141_3D.root 1691111970.0 UPDATE `SlowReco` SET `run_epoch`='1691111970.0' WHERE `run_mean` = '24141';
# 24140.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24140_3D.root 1691111553.0 UPDATE `SlowReco` SET `run_epoch`='1691111553.0' WHERE `run_mean` = '24140';
# 24139.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24139_3D.root 1691111151.0 UPDATE `SlowReco` SET `run_epoch`='1691111151.0' WHERE `run_mean` = '24139';
# 24138.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24138_3D.root 1691110743.0 UPDATE `SlowReco` SET `run_epoch`='1691110743.0' WHERE `run_mean` = '24138';
# 24137.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24137_3D.root 1691110352.0 UPDATE `SlowReco` SET `run_epoch`='1691110352.0' WHERE `run_mean` = '24137';
# 24136.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24136_3D.root 1691109958.0 UPDATE `SlowReco` SET `run_epoch`='1691109958.0' WHERE `run_mean` = '24136';
# 24135.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24135_3D.root 1691109561.0 UPDATE `SlowReco` SET `run_epoch`='1691109561.0' WHERE `run_mean` = '24135';
# 24134.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24134_3D.root 1691109153.0 UPDATE `SlowReco` SET `run_epoch`='1691109153.0' WHERE `run_mean` = '24134';
# 24132.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24132_3D.root 1691108503.0 UPDATE `SlowReco` SET `run_epoch`='1691108503.0' WHERE `run_mean` = '24132';
# 24131.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24131_3D.root 1691108076.0 UPDATE `SlowReco` SET `run_epoch`='1691108076.0' WHERE `run_mean` = '24131';
# 24130.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24130_3D.root 1691107675.0 UPDATE `SlowReco` SET `run_epoch`='1691107675.0' WHERE `run_mean` = '24130';
# 24129.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24129_3D.root 1691107294.0 UPDATE `SlowReco` SET `run_epoch`='1691107294.0' WHERE `run_mean` = '24129';
# 24128.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24128_3D.root 1691106903.0 UPDATE `SlowReco` SET `run_epoch`='1691106903.0' WHERE `run_mean` = '24128';
# 24126.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24126_3D.root 1691106087.0 UPDATE `SlowReco` SET `run_epoch`='1691106087.0' WHERE `run_mean` = '24126';
# 24125.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24125_3D.root 1691105670.0 UPDATE `SlowReco` SET `run_epoch`='1691105670.0' WHERE `run_mean` = '24125';
# 24124.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24124_3D.root 1691105248.0 UPDATE `SlowReco` SET `run_epoch`='1691105248.0' WHERE `run_mean` = '24124';
# 24123.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24123_3D.root 1691104825.0 UPDATE `SlowReco` SET `run_epoch`='1691104825.0' WHERE `run_mean` = '24123';
# 24121.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24121_3D.root 1691104212.0 UPDATE `SlowReco` SET `run_epoch`='1691104212.0' WHERE `run_mean` = '24121';
# 24120.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24120_3D.root 1691103805.0 UPDATE `SlowReco` SET `run_epoch`='1691103805.0' WHERE `run_mean` = '24120';
# 24119.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24119_3D.root 1691103407.0 UPDATE `SlowReco` SET `run_epoch`='1691103407.0' WHERE `run_mean` = '24119';
# 24118.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24118_3D.root 1691102996.0 UPDATE `SlowReco` SET `run_epoch`='1691102996.0' WHERE `run_mean` = '24118';
# 24117.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24117_3D.root 1691102577.0 UPDATE `SlowReco` SET `run_epoch`='1691102577.0' WHERE `run_mean` = '24117';
# 24116.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24116_3D.root 1691102186.0 UPDATE `SlowReco` SET `run_epoch`='1691102186.0' WHERE `run_mean` = '24116';
# 24115.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24115_3D.root 1691101766.0 UPDATE `SlowReco` SET `run_epoch`='1691101766.0' WHERE `run_mean` = '24115';
# 24114.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24114_3D.root 1691101369.0 UPDATE `SlowReco` SET `run_epoch`='1691101369.0' WHERE `run_mean` = '24114';
# 24113.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24113_3D.root 1691100969.0 UPDATE `SlowReco` SET `run_epoch`='1691100969.0' WHERE `run_mean` = '24113';
# 24112.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24112_3D.root 1691100552.0 UPDATE `SlowReco` SET `run_epoch`='1691100552.0' WHERE `run_mean` = '24112';
# 24110.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24110_3D.root 1691099940.0 UPDATE `SlowReco` SET `run_epoch`='1691099940.0' WHERE `run_mean` = '24110';
# 24109.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24109_3D.root 1691099532.0 UPDATE `SlowReco` SET `run_epoch`='1691099532.0' WHERE `run_mean` = '24109';
# 24108.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24108_3D.root 1691099105.0 UPDATE `SlowReco` SET `run_epoch`='1691099105.0' WHERE `run_mean` = '24108';
# 24107.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24107_3D.root 1691098694.0 UPDATE `SlowReco` SET `run_epoch`='1691098694.0' WHERE `run_mean` = '24107';
# 24106.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24106_3D.root 1691098267.0 UPDATE `SlowReco` SET `run_epoch`='1691098267.0' WHERE `run_mean` = '24106';
# 24105.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24105_3D.root 1691097840.0 UPDATE `SlowReco` SET `run_epoch`='1691097840.0' WHERE `run_mean` = '24105';
# 24104.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24104_3D.root 1691097430.0 UPDATE `SlowReco` SET `run_epoch`='1691097430.0' WHERE `run_mean` = '24104';
# 24103.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24103_3D.root 1691097008.0 UPDATE `SlowReco` SET `run_epoch`='1691097008.0' WHERE `run_mean` = '24103';
# 24102.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24102_3D.root 1691096591.0 UPDATE `SlowReco` SET `run_epoch`='1691096591.0' WHERE `run_mean` = '24102';
# 24101.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24101_3D.root 1691096171.0 UPDATE `SlowReco` SET `run_epoch`='1691096171.0' WHERE `run_mean` = '24101';
# 24099.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24099_3D.root 1691095541.0 UPDATE `SlowReco` SET `run_epoch`='1691095541.0' WHERE `run_mean` = '24099';
# 24098.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24098_3D.root 1691095134.0 UPDATE `SlowReco` SET `run_epoch`='1691095134.0' WHERE `run_mean` = '24098';
# 24097.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24097_3D.root 1691094713.0 UPDATE `SlowReco` SET `run_epoch`='1691094713.0' WHERE `run_mean` = '24097';
# 24096.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24096_3D.root 1691094299.0 UPDATE `SlowReco` SET `run_epoch`='1691094299.0' WHERE `run_mean` = '24096';
# 24095.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24095_3D.root 1691093880.0 UPDATE `SlowReco` SET `run_epoch`='1691093880.0' WHERE `run_mean` = '24095';
# 24094.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24094_3D.root 1691093478.0 UPDATE `SlowReco` SET `run_epoch`='1691093478.0' WHERE `run_mean` = '24094';
# 24093.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24093_3D.root 1691093070.0 UPDATE `SlowReco` SET `run_epoch`='1691093070.0' WHERE `run_mean` = '24093';
# 24092.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24092_3D.root 1691092671.0 UPDATE `SlowReco` SET `run_epoch`='1691092671.0' WHERE `run_mean` = '24092';
# 24091.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24091_3D.root 1691092249.0 UPDATE `SlowReco` SET `run_epoch`='1691092249.0' WHERE `run_mean` = '24091';
# 24090.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24090_3D.root 1691091848.0 UPDATE `SlowReco` SET `run_epoch`='1691091848.0' WHERE `run_mean` = '24090';
# 24088.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24088_3D.root 1691091220.0 UPDATE `SlowReco` SET `run_epoch`='1691091220.0' WHERE `run_mean` = '24088';
# 24087.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24087_3D.root 1691090809.0 UPDATE `SlowReco` SET `run_epoch`='1691090809.0' WHERE `run_mean` = '24087';
# 24086.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24086_3D.root 1691090390.0 UPDATE `SlowReco` SET `run_epoch`='1691090390.0' WHERE `run_mean` = '24086';
# 24085.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24085_3D.root 1691089989.0 UPDATE `SlowReco` SET `run_epoch`='1691089989.0' WHERE `run_mean` = '24085';
# 24084.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24084_3D.root 1691089588.0 UPDATE `SlowReco` SET `run_epoch`='1691089588.0' WHERE `run_mean` = '24084';
# 24083.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24083_3D.root 1691089191.0 UPDATE `SlowReco` SET `run_epoch`='1691089191.0' WHERE `run_mean` = '24083';
# 24082.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24082_3D.root 1691088791.0 UPDATE `SlowReco` SET `run_epoch`='1691088791.0' WHERE `run_mean` = '24082';
# 24081.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24081_3D.root 1691088402.0 UPDATE `SlowReco` SET `run_epoch`='1691088402.0' WHERE `run_mean` = '24081';
# 24080.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24080_3D.root 1691087972.0 UPDATE `SlowReco` SET `run_epoch`='1691087972.0' WHERE `run_mean` = '24080';
# 24079.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24079_3D.root 1691087573.0 UPDATE `SlowReco` SET `run_epoch`='1691087573.0' WHERE `run_mean` = '24079';
# 24077.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24077_3D.root 1691086940.0 UPDATE `SlowReco` SET `run_epoch`='1691086940.0' WHERE `run_mean` = '24077';
# 24076.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24076_3D.root 1691086523.0 UPDATE `SlowReco` SET `run_epoch`='1691086523.0' WHERE `run_mean` = '24076';
# 24075.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24075_3D.root 1691086101.0 UPDATE `SlowReco` SET `run_epoch`='1691086101.0' WHERE `run_mean` = '24075';
# 24074.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24074_3D.root 1691085693.0 UPDATE `SlowReco` SET `run_epoch`='1691085693.0' WHERE `run_mean` = '24074';
# 24073.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24073_3D.root 1691085276.0 UPDATE `SlowReco` SET `run_epoch`='1691085276.0' WHERE `run_mean` = '24073';
# 24072.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24072_3D.root 1691084868.0 UPDATE `SlowReco` SET `run_epoch`='1691084868.0' WHERE `run_mean` = '24072';
# 24071.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24071_3D.root 1691084455.0 UPDATE `SlowReco` SET `run_epoch`='1691084455.0' WHERE `run_mean` = '24071';
# 24070.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24070_3D.root 1691084052.0 UPDATE `SlowReco` SET `run_epoch`='1691084052.0' WHERE `run_mean` = '24070';
# 24069.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24069_3D.root 1691083633.0 UPDATE `SlowReco` SET `run_epoch`='1691083633.0' WHERE `run_mean` = '24069';
# 24068.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24068_3D.root 1691083232.0 UPDATE `SlowReco` SET `run_epoch`='1691083232.0' WHERE `run_mean` = '24068';
# 24066.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24066_3D.root 1691082621.0 UPDATE `SlowReco` SET `run_epoch`='1691082621.0' WHERE `run_mean` = '24066';
# 24065.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24065_3D.root 1691082204.0 UPDATE `SlowReco` SET `run_epoch`='1691082204.0' WHERE `run_mean` = '24065';
# 24064.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24064_3D.root 1691081784.0 UPDATE `SlowReco` SET `run_epoch`='1691081784.0' WHERE `run_mean` = '24064';
# 24063.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24063_3D.root 1691081365.0 UPDATE `SlowReco` SET `run_epoch`='1691081365.0' WHERE `run_mean` = '24063';
# 24062.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24062_3D.root 1691080962.0 UPDATE `SlowReco` SET `run_epoch`='1691080962.0' WHERE `run_mean` = '24062';
# 24061.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24061_3D.root 1691080563.0 UPDATE `SlowReco` SET `run_epoch`='1691080563.0' WHERE `run_mean` = '24061';
# 24060.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24060_3D.root 1691080134.0 UPDATE `SlowReco` SET `run_epoch`='1691080134.0' WHERE `run_mean` = '24060';
# 24058.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24058_3D.root 1691079315.0 UPDATE `SlowReco` SET `run_epoch`='1691079315.0' WHERE `run_mean` = '24058';
# 24057.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24057_3D.root 1691078876.0 UPDATE `SlowReco` SET `run_epoch`='1691078876.0' WHERE `run_mean` = '24057';
# 24055.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24055_3D.root 1691078262.0 UPDATE `SlowReco` SET `run_epoch`='1691078262.0' WHERE `run_mean` = '24055';
# 24054.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24054_3D.root 1691077835.0 UPDATE `SlowReco` SET `run_epoch`='1691077835.0' WHERE `run_mean` = '24054';
# 24053.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24053_3D.root 1691077445.0 UPDATE `SlowReco` SET `run_epoch`='1691077445.0' WHERE `run_mean` = '24053';
# 24052.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24052_3D.root 1691077042.0 UPDATE `SlowReco` SET `run_epoch`='1691077042.0' WHERE `run_mean` = '24052';
# 24051.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24051_3D.root 1691076620.0 UPDATE `SlowReco` SET `run_epoch`='1691076620.0' WHERE `run_mean` = '24051';
# 24050.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24050_3D.root 1691076201.0 UPDATE `SlowReco` SET `run_epoch`='1691076201.0' WHERE `run_mean` = '24050';
# 24049.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24049_3D.root 1691075797.0 UPDATE `SlowReco` SET `run_epoch`='1691075797.0' WHERE `run_mean` = '24049';
# 24048.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24048_3D.root 1691075405.0 UPDATE `SlowReco` SET `run_epoch`='1691075405.0' WHERE `run_mean` = '24048';
# 24047.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24047_3D.root 1691075001.0 UPDATE `SlowReco` SET `run_epoch`='1691075001.0' WHERE `run_mean` = '24047';
# 24046.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24046_3D.root 1691074594.0 UPDATE `SlowReco` SET `run_epoch`='1691074594.0' WHERE `run_mean` = '24046';
# 24044.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24044_3D.root 1691073957.0 UPDATE `SlowReco` SET `run_epoch`='1691073957.0' WHERE `run_mean` = '24044';
# 24043.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24043_3D.root 1691073568.0 UPDATE `SlowReco` SET `run_epoch`='1691073568.0' WHERE `run_mean` = '24043';
# 24042.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24042_3D.root 1691073171.0 UPDATE `SlowReco` SET `run_epoch`='1691073171.0' WHERE `run_mean` = '24042';
# 24041.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24041_3D.root 1691072753.0 UPDATE `SlowReco` SET `run_epoch`='1691072753.0' WHERE `run_mean` = '24041';
# 24040.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24040_3D.root 1691072341.0 UPDATE `SlowReco` SET `run_epoch`='1691072341.0' WHERE `run_mean` = '24040';
# 24039.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24039_3D.root 1691071963.0 UPDATE `SlowReco` SET `run_epoch`='1691071963.0' WHERE `run_mean` = '24039';
# 24038.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24038_3D.root 1691071553.0 UPDATE `SlowReco` SET `run_epoch`='1691071553.0' WHERE `run_mean` = '24038';
# 24037.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24037_3D.root 1691071106.0 UPDATE `SlowReco` SET `run_epoch`='1691071106.0' WHERE `run_mean` = '24037';
# 24036.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24036_3D.root 1691070698.0 UPDATE `SlowReco` SET `run_epoch`='1691070698.0' WHERE `run_mean` = '24036';
# 24035.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24035_3D.root 1691070309.0 UPDATE `SlowReco` SET `run_epoch`='1691070309.0' WHERE `run_mean` = '24035';
# 24033.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24033_3D.root 1691069694.0 UPDATE `SlowReco` SET `run_epoch`='1691069694.0' WHERE `run_mean` = '24033';
# 24032.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24032_3D.root 1691069286.0 UPDATE `SlowReco` SET `run_epoch`='1691069286.0' WHERE `run_mean` = '24032';
# 24031.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24031_3D.root 1691068899.0 UPDATE `SlowReco` SET `run_epoch`='1691068899.0' WHERE `run_mean` = '24031';
# 24030.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24030_3D.root 1691068488.0 UPDATE `SlowReco` SET `run_epoch`='1691068488.0' WHERE `run_mean` = '24030';
# 24029.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24029_3D.root 1691068069.0 UPDATE `SlowReco` SET `run_epoch`='1691068069.0' WHERE `run_mean` = '24029';
# 24028.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24028_3D.root 1691067691.0 UPDATE `SlowReco` SET `run_epoch`='1691067691.0' WHERE `run_mean` = '24028';
# 24027.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24027_3D.root 1691067283.0 UPDATE `SlowReco` SET `run_epoch`='1691067283.0' WHERE `run_mean` = '24027';
# 24026.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24026_3D.root 1691066899.0 UPDATE `SlowReco` SET `run_epoch`='1691066899.0' WHERE `run_mean` = '24026';
# 24025.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24025_3D.root 1691066492.0 UPDATE `SlowReco` SET `run_epoch`='1691066492.0' WHERE `run_mean` = '24025';
# 24024.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24024_3D.root 1691066078.0 UPDATE `SlowReco` SET `run_epoch`='1691066078.0' WHERE `run_mean` = '24024';
# 24022.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24022_3D.root 1691065556.0 UPDATE `SlowReco` SET `run_epoch`='1691065556.0' WHERE `run_mean` = '24022';
# 24021.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24021_3D.root 1691065314.0 UPDATE `SlowReco` SET `run_epoch`='1691065314.0' WHERE `run_mean` = '24021';
# 24019.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24019_3D.root 1691064856.0 UPDATE `SlowReco` SET `run_epoch`='1691064856.0' WHERE `run_mean` = '24019';
# 24018.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24018_3D.root 1691064613.0 UPDATE `SlowReco` SET `run_epoch`='1691064613.0' WHERE `run_mean` = '24018';
# 24017.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24017_3D.root 1691064373.0 UPDATE `SlowReco` SET `run_epoch`='1691064373.0' WHERE `run_mean` = '24017';
# 24016.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24016_3D.root 1691064133.0 UPDATE `SlowReco` SET `run_epoch`='1691064133.0' WHERE `run_mean` = '24016';
# 24015.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24015_3D.root 1691063891.0 UPDATE `SlowReco` SET `run_epoch`='1691063891.0' WHERE `run_mean` = '24015';
# 24014.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24014_3D.root 1691063648.0 UPDATE `SlowReco` SET `run_epoch`='1691063648.0' WHERE `run_mean` = '24014';
# 24013.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24013_3D.root 1691063408.0 UPDATE `SlowReco` SET `run_epoch`='1691063408.0' WHERE `run_mean` = '24013';
# 24012.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24012_3D.root 1691063166.0 UPDATE `SlowReco` SET `run_epoch`='1691063166.0' WHERE `run_mean` = '24012';
# 24011.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24011_3D.root 1691062923.0 UPDATE `SlowReco` SET `run_epoch`='1691062923.0' WHERE `run_mean` = '24011';
# 24010.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24010_3D.root 1691062682.0 UPDATE `SlowReco` SET `run_epoch`='1691062682.0' WHERE `run_mean` = '24010';
# 24008.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24008_3D.root 1691062221.0 UPDATE `SlowReco` SET `run_epoch`='1691062221.0' WHERE `run_mean` = '24008';
# 24007.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24007_3D.root 1691061982.0 UPDATE `SlowReco` SET `run_epoch`='1691061982.0' WHERE `run_mean` = '24007';
# 24006.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24006_3D.root 1691061741.0 UPDATE `SlowReco` SET `run_epoch`='1691061741.0' WHERE `run_mean` = '24006';
# 24005.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24005_3D.root 1691061501.0 UPDATE `SlowReco` SET `run_epoch`='1691061501.0' WHERE `run_mean` = '24005';
# 24003.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24003_3D.root 1691061020.0 UPDATE `SlowReco` SET `run_epoch`='1691061020.0' WHERE `run_mean` = '24003';
# 24002.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24002_3D.root 1691060780.0 UPDATE `SlowReco` SET `run_epoch`='1691060780.0' WHERE `run_mean` = '24002';
# 24001.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24001_3D.root 1691060540.0 UPDATE `SlowReco` SET `run_epoch`='1691060540.0' WHERE `run_mean` = '24001';
# 24000.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run24000_3D.root 1691060298.0 UPDATE `SlowReco` SET `run_epoch`='1691060298.0' WHERE `run_mean` = '24000';
# 23999.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23999_3D.root 1691060058.0 UPDATE `SlowReco` SET `run_epoch`='1691060058.0' WHERE `run_mean` = '23999';
# 23997.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23997_3D.root 1691059603.0 UPDATE `SlowReco` SET `run_epoch`='1691059603.0' WHERE `run_mean` = '23997';
# 23995.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23995_3D.root 1691059116.0 UPDATE `SlowReco` SET `run_epoch`='1691059116.0' WHERE `run_mean` = '23995';
# 23994.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23994_3D.root 1691058875.0 UPDATE `SlowReco` SET `run_epoch`='1691058875.0' WHERE `run_mean` = '23994';
# 23993.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23993_3D.root 1691058634.0 UPDATE `SlowReco` SET `run_epoch`='1691058634.0' WHERE `run_mean` = '23993';
# 23992.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23992_3D.root 1691058394.0 UPDATE `SlowReco` SET `run_epoch`='1691058394.0' WHERE `run_mean` = '23992';
# 23991.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23991_3D.root 1691058155.0 UPDATE `SlowReco` SET `run_epoch`='1691058155.0' WHERE `run_mean` = '23991';
# 23990.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23990_3D.root 1691057915.0 UPDATE `SlowReco` SET `run_epoch`='1691057915.0' WHERE `run_mean` = '23990';
# 23989.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23989_3D.root 1691057673.0 UPDATE `SlowReco` SET `run_epoch`='1691057673.0' WHERE `run_mean` = '23989';
# 23988.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23988_3D.root 1691057429.0 UPDATE `SlowReco` SET `run_epoch`='1691057429.0' WHERE `run_mean` = '23988';
# 23986.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23986_3D.root 1691057163.0 UPDATE `SlowReco` SET `run_epoch`='1691057163.0' WHERE `run_mean` = '23986';
# 23983.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23983_3D.root 1691056144.0 UPDATE `SlowReco` SET `run_epoch`='1691056144.0' WHERE `run_mean` = '23983';
# 23982.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23982_3D.root 1691055714.0 UPDATE `SlowReco` SET `run_epoch`='1691055714.0' WHERE `run_mean` = '23982';
# 23981.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23981_3D.root 1691055295.0 UPDATE `SlowReco` SET `run_epoch`='1691055295.0' WHERE `run_mean` = '23981';
# 23980.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23980_3D.root 1691054883.0 UPDATE `SlowReco` SET `run_epoch`='1691054883.0' WHERE `run_mean` = '23980';
# 23979.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23979_3D.root 1691054469.0 UPDATE `SlowReco` SET `run_epoch`='1691054469.0' WHERE `run_mean` = '23979';
# 23978.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23978_3D.root 1691054082.0 UPDATE `SlowReco` SET `run_epoch`='1691054082.0' WHERE `run_mean` = '23978';
# 23977.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23977_3D.root 1691053685.0 UPDATE `SlowReco` SET `run_epoch`='1691053685.0' WHERE `run_mean` = '23977';
# 23976.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23976_3D.root 1691053291.0 UPDATE `SlowReco` SET `run_epoch`='1691053291.0' WHERE `run_mean` = '23976';
# 23975.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23975_3D.root 1691052862.0 UPDATE `SlowReco` SET `run_epoch`='1691052862.0' WHERE `run_mean` = '23975';
# 23974.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23974_3D.root 1691052454.0 UPDATE `SlowReco` SET `run_epoch`='1691052454.0' WHERE `run_mean` = '23974';
# 23972.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23972_3D.root 1691051827.0 UPDATE `SlowReco` SET `run_epoch`='1691051827.0' WHERE `run_mean` = '23972';
# 23971.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23971_3D.root 1691051400.0 UPDATE `SlowReco` SET `run_epoch`='1691051400.0' WHERE `run_mean` = '23971';
# 23970.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23970_3D.root 1691050982.0 UPDATE `SlowReco` SET `run_epoch`='1691050982.0' WHERE `run_mean` = '23970';
# 23969.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23969_3D.root 1691050575.0 UPDATE `SlowReco` SET `run_epoch`='1691050575.0' WHERE `run_mean` = '23969';
# 23968.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23968_3D.root 1691050158.0 UPDATE `SlowReco` SET `run_epoch`='1691050158.0' WHERE `run_mean` = '23968';
# 23967.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23967_3D.root 1691049760.0 UPDATE `SlowReco` SET `run_epoch`='1691049760.0' WHERE `run_mean` = '23967';
# 23966.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23966_3D.root 1691049363.0 UPDATE `SlowReco` SET `run_epoch`='1691049363.0' WHERE `run_mean` = '23966';
# 23965.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23965_3D.root 1691048966.0 UPDATE `SlowReco` SET `run_epoch`='1691048966.0' WHERE `run_mean` = '23965';
# 23964.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23964_3D.root 1691048546.0 UPDATE `SlowReco` SET `run_epoch`='1691048546.0' WHERE `run_mean` = '23964';
# 23963.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23963_3D.root 1691048134.0 UPDATE `SlowReco` SET `run_epoch`='1691048134.0' WHERE `run_mean` = '23963';
# 23961.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23961_3D.root 1691047489.0 UPDATE `SlowReco` SET `run_epoch`='1691047489.0' WHERE `run_mean` = '23961';
# 23960.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23960_3D.root 1691047068.0 UPDATE `SlowReco` SET `run_epoch`='1691047068.0' WHERE `run_mean` = '23960';
# 23959.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23959_3D.root 1691046635.0 UPDATE `SlowReco` SET `run_epoch`='1691046635.0' WHERE `run_mean` = '23959';
# 23958.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23958_3D.root 1691046218.0 UPDATE `SlowReco` SET `run_epoch`='1691046218.0' WHERE `run_mean` = '23958';
# 23957.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23957_3D.root 1691045810.0 UPDATE `SlowReco` SET `run_epoch`='1691045810.0' WHERE `run_mean` = '23957';
# 23956.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23956_3D.root 1691045411.0 UPDATE `SlowReco` SET `run_epoch`='1691045411.0' WHERE `run_mean` = '23956';
# 23955.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23955_3D.root 1691045001.0 UPDATE `SlowReco` SET `run_epoch`='1691045001.0' WHERE `run_mean` = '23955';
# 23954.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23954_3D.root 1691044590.0 UPDATE `SlowReco` SET `run_epoch`='1691044590.0' WHERE `run_mean` = '23954';
# 23953.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23953_3D.root 1691044187.0 UPDATE `SlowReco` SET `run_epoch`='1691044187.0' WHERE `run_mean` = '23953';
# 23952.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23952_3D.root 1691043777.0 UPDATE `SlowReco` SET `run_epoch`='1691043777.0' WHERE `run_mean` = '23952';
# 23950.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23950_3D.root 1691043144.0 UPDATE `SlowReco` SET `run_epoch`='1691043144.0' WHERE `run_mean` = '23950';
# 23949.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23949_3D.root 1691042706.0 UPDATE `SlowReco` SET `run_epoch`='1691042706.0' WHERE `run_mean` = '23949';
# 23948.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23948_3D.root 1691042304.0 UPDATE `SlowReco` SET `run_epoch`='1691042304.0' WHERE `run_mean` = '23948';
# 23947.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23947_3D.root 1691041883.0 UPDATE `SlowReco` SET `run_epoch`='1691041883.0' WHERE `run_mean` = '23947';
# 23946.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23946_3D.root 1691041474.0 UPDATE `SlowReco` SET `run_epoch`='1691041474.0' WHERE `run_mean` = '23946';
# 23945.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23945_3D.root 1691041047.0 UPDATE `SlowReco` SET `run_epoch`='1691041047.0' WHERE `run_mean` = '23945';
# 23944.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23944_3D.root 1691040638.0 UPDATE `SlowReco` SET `run_epoch`='1691040638.0' WHERE `run_mean` = '23944';
# 23943.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23943_3D.root 1691040235.0 UPDATE `SlowReco` SET `run_epoch`='1691040235.0' WHERE `run_mean` = '23943';
# 23942.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23942_3D.root 1691039825.0 UPDATE `SlowReco` SET `run_epoch`='1691039825.0' WHERE `run_mean` = '23942';
# 23939.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23939_3D.root 1691038783.0 UPDATE `SlowReco` SET `run_epoch`='1691038783.0' WHERE `run_mean` = '23939';
# 23938.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23938_3D.root 1691038365.0 UPDATE `SlowReco` SET `run_epoch`='1691038365.0' WHERE `run_mean` = '23938';
# 23937.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23937_3D.root 1691037948.0 UPDATE `SlowReco` SET `run_epoch`='1691037948.0' WHERE `run_mean` = '23937';
# 23936.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23936_3D.root 1691037557.0 UPDATE `SlowReco` SET `run_epoch`='1691037557.0' WHERE `run_mean` = '23936';
# 23935.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23935_3D.root 1691037169.0 UPDATE `SlowReco` SET `run_epoch`='1691037169.0' WHERE `run_mean` = '23935';
# 23934.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23934_3D.root 1691036750.0 UPDATE `SlowReco` SET `run_epoch`='1691036750.0' WHERE `run_mean` = '23934';
# 23933.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23933_3D.root 1691036352.0 UPDATE `SlowReco` SET `run_epoch`='1691036352.0' WHERE `run_mean` = '23933';
# 23932.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23932_3D.root 1691035954.0 UPDATE `SlowReco` SET `run_epoch`='1691035954.0' WHERE `run_mean` = '23932';
# 23931.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23931_3D.root 1691035537.0 UPDATE `SlowReco` SET `run_epoch`='1691035537.0' WHERE `run_mean` = '23931';
# 23930.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23930_3D.root 1691035139.0 UPDATE `SlowReco` SET `run_epoch`='1691035139.0' WHERE `run_mean` = '23930';
# 23928.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23928_3D.root 1691034512.0 UPDATE `SlowReco` SET `run_epoch`='1691034512.0' WHERE `run_mean` = '23928';
# 23926.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23926_3D.root 1691033703.0 UPDATE `SlowReco` SET `run_epoch`='1691033703.0' WHERE `run_mean` = '23926';
# 23925.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23925_3D.root 1691033279.0 UPDATE `SlowReco` SET `run_epoch`='1691033279.0' WHERE `run_mean` = '23925';
# 23924.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23924_3D.root 1691032872.0 UPDATE `SlowReco` SET `run_epoch`='1691032872.0' WHERE `run_mean` = '23924';
# 23923.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23923_3D.root 1691032441.0 UPDATE `SlowReco` SET `run_epoch`='1691032441.0' WHERE `run_mean` = '23923';
# 23922.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23922_3D.root 1691032041.0 UPDATE `SlowReco` SET `run_epoch`='1691032041.0' WHERE `run_mean` = '23922';
# 23921.0 https://s3.cloud.infn.it/v1/AUTH_2ebf769785574195bde2ff418deac08a/cygno-analysis/RECO/Winter23/reco_run23921_3D.root 1691031633.0 UPDATE `SlowReco` SET `run_epoch`='1691031633.0' WHERE `run_mean` = '23921';

# %%
con
